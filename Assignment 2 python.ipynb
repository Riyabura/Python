# %% [markdown]
# **Python Lab Assignment 2**
#
# **PRN No:** 1132220355
# **Name:** Riya Narayan Bura

# %% [markdown]
# **Example 1**

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

data = np.array(list(zip(x, y)))

linkage_data = linkage(data, method='ward', metric='euclidean')
dendrogram(linkage_data)

plt.title('Dendrogram')
plt.xlabel('Data points')
plt.ylabel('Distance')

print(data)
plt.show()
# Out:
# [[ 4 21]
#  [ 5 19]
#  [10 24]
#  [ 4 17]
#  [ 3 16]
#  [11 25]
#  [14 24]
#  [ 6 22]
#  [10 21]
#  [12 21]]

# %% [markdown]
# **Example 2**

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

data = np.array(list(zip(x, y)))

linkage_data = linkage(data, method='single', metric='euclidean')
dendrogram(linkage_data)

plt.title('Dendrogram')
plt.xlabel('Data points')
plt.ylabel('Distance')

print(data)
plt.show()
# Out:
# [[ 4 21]
#  [ 5 19]
#  [10 24]
#  [ 4 17]
#  [ 3 16]
#  [11 25]
#  [14 24]
#  [ 6 22]
#  [10 21]
#  [12 21]]

# %% [markdown]
# **Example 3**

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

data = np.array(list(zip(x, y)))

linkage_data = linkage(data, method='average', metric='euclidean')
dendrogram(linkage_data)

plt.title('Dendrogram')
plt.xlabel('Data points')
plt.ylabel('Distance')

print(data)
plt.show()
# Out:
# [[ 4 21]
#  [ 5 19]
#  [10 24]
#  [ 4 17]
#  [ 3 16]
#  [11 25]
#  [14 24]
#  [ 6 22]
#  [10 21]
#  [12 21]]

# %% [markdown]
# **Example 4**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

data = np.array(list(zip(x, y)))

hierarchical_cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
labels = hierarchical_cluster.fit_predict(data)

plt.scatter(x, y, c=labels)
plt.title('Agglomerative Clustering')
plt.xlabel('x')
plt.ylabel('y')

print(data)
plt.show()
# Out:
# [[ 4 21]
#  [ 5 19]
#  [10 24]
#  [ 4 17]
#  [ 3 16]
#  [11 25]
#  [14 24]
#  [ 6 22]
#  [10 21]
#  [12 21]]

# %% [markdown]
# **Example 5**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch

# Load data from CSV file
data = pd.read_csv(r'C:\Users\hp\Downloads\Mall_Customers (1) - Mall_Customers (1).csv')

# Check the head of the data
print(data.head())

# Extract last two columns
X = data.iloc[:, 3:5].values

# Plot dendrogram using ward method
plt.figure(figsize=(10, 7))
plt.title("Dendrogram (Ward)")
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))

# Plot dendrogram using single method
plt.figure(figsize=(10, 7))
plt.title("Dendrogram (Single)")
dendrogram = sch.dendrogram(sch.linkage(X, method='single'))

# Plot dendrogram using average method
plt.figure(figsize=(10, 7))
plt.title("Dendrogram (Average)")
dendrogram = sch.dendrogram(sch.linkage(X, method='average'))

plt.show()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
